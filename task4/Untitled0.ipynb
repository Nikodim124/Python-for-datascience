# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
a = np.genfromtxt('out.csv',delimiter=',',skip_header=True)
ematrix = np.eye(*a.shape)
res = np.dot(a, ematrix.transpose())
np.savetxt("new_out.csv", res, delimiter=",")

# %%
a = pd.read_csv('new_out.csv', header=None)
a = pd.DataFrame(np.random.randint(0,100, size=(len(a),len(a.columns.to_list()))), columns=a.columns.to_list())
a
# Out:
#     0   1   2   3   4   5   6   7   8   ...  14  15  16  17  18  19  20  21  22
# 0   42  49  99  97  50   5  80  10  84  ...   0  61  12  39  16  84  89  46  62
# 1   58  54  44  76  33  25  46  79  99  ...  59  83  57   3  56  46  88  11  30
# 2   10  25  84  55  38   6  54  97  87  ...  48  47  76  11   0  60   5   0  50
# 3   37  26  63  66  77  54  61  91  84  ...  40  25  62  13  36  12  84  47  70
# 4   45  69  84   7  43   7  76  30  43  ...  10  63  28  78   5  94  15  34  26
# 5   19  85  59  52  88   1  24  48  26  ...  58  71  45  51  74  29  70  64  34
# 6   69  38  84  79  89  56  87   6  89  ...  48  51  37  53  57  13  26  53  74
# 7   32  58   5  66  59  36  33  51  55  ...   9  50  99  40  21  18  77  59  74
# 8   62  36  44  33   9   9  94  24  77  ...  55  32   8  58  80  87  72  22  28
# 9   55  31  96  26  56  91  18  60  94  ...  14  64   5  12  40  32  65  21  37
# 10  61  94  21  60   4  68  80  31  88  ...   8  59  41  43  89  35  76  60  40
# ...

# %%
threedee = plt.figure().gca(projection='3d')
threedee.scatter(np.random.random(207), a[1:10], a[11:20])
plt.show()
